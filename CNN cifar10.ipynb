# %%
import tensorflow as tf
from tensorflow.keras import datasets , layers , models
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train , y_train) , (x_test , y_test) = datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
x_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
plt.figure(figsize=(15,2))
plt.imshow(x_train[0])

# %%
plt.figure(figsize=(15,2))
plt.imshow(x_train[8])

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
y_train = y_train.reshape(-1,)
y_train[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
classes = ['airplane','automobile','bird','cat','dear','dog','frog','horse','ship','truck']

# %%
classes[9]
# Out:
# 'truck'

# %%
def plot_sample(x,y,index):
    plt.figure(figsize=(15,2))
    plt.imshow(x[index])
    plt.xlabel(classes[y[index]])

# %%
x_train = x_train/255.0
x_test = x_test / 255.0

# %% [markdown]
# # Artificia nural network

# %%
ann = models.Sequential([
        layers.Flatten(input_shape=(32,32,3)),
        layers.Dense(3000, activation='relu'),
        layers.Dense(1000, activation='relu'),
        layers.Dense(10, activation='sigmoid')    
    ])

bbb
ann.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 95s 60ms/step - loss: 1.8166 - accuracy: 0.3523
# Epoch 2/5
# 1563/1563 [==============================] - 93s 60ms/step - loss: 1.6270 - accuracy: 0.4253
# Epoch 3/5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.5441 - accuracy: 0.4541
# Epoch 4/5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.4840 - accuracy: 0.4765
# Epoch 5/5
# 1563/1563 [==============================] - 95s 60ms/step - loss: 1.4359 - accuracy: 0.4928

# %%
ann.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 1.4490 - accuracy: 0.4852
# [1.4489693641662598, 0.4851999878883362]

# %%
bb
# Out:
# 313/313 [==============================] - 4s 12ms/step
# classification Report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.70      0.57      1000
#            1       0.63      0.58      0.60      1000
#            2       0.39      0.36      0.37      1000
#            3       0.34      0.28      0.30      1000
#            4       0.54      0.26      0.35      1000
#            5       0.34      0.46      0.39      1000
#            6       0.49      0.60      0.54      1000
#            7       0.56      0.54      0.55      1000
#            8       0.76      0.44      0.56      1000
#            9       0.50      0.64      0.56      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.50      0.49      0.48     10000
# weighted avg       0.50      0.49      0.48     10000

# %%
cnn = models.Sequential([
    #cnn
    layers.Conv2D(filters=32 , kernel_size=(3,3),activation='relu',input_shape=(32,32,3)),
    layers.MaxPooling2D(2,2),
    
    layers.Conv2D(filters=68 , kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D(2,2),
    #dense
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(10,activation='softmax')
    
])

# %%
cnn.compile(optimizer='adam',
           loss =  'sparse_categorical_crossentropy',
           metrics=['accuracy'])

# %%
cnn.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 39s 24ms/step - loss: 1.4391 - accuracy: 0.4838
# Epoch 2/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.0996 - accuracy: 0.6162
# Epoch 3/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.9790 - accuracy: 0.6584
# Epoch 4/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.8963 - accuracy: 0.6900
# Epoch 5/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.8322 - accuracy: 0.7125
# Epoch 6/10
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7791 - accuracy: 0.7289
# Epoch 7/10
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7324 - accuracy: 0.7450
# Epoch 8/10
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6921 - accuracy: 0.7588
# Epoch 9/10
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6571 - accuracy: 0.7713
# Epoch 10/10
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6204 - accuracy: 0.7837

# %%
cnn.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9293 - accuracy: 0.6954
# [0.929314374923706, 0.6953999996185303]

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
y_test =y_test.reshape(-1,)
y_test[:6]
# Out:
# array([3, 8, 8, 0, 6, 6], dtype=uint8)

# %%
plot_sample(x_test,y_test,1)

# %%
y_pred = cnn.predict(x_test)
y_pred[:6]
# Out:
# 313/313 [==============================] - 3s 8ms/step
# array([[7.09658430e-04, 5.45909221e-04, 4.23037866e-03, 9.41022456e-01,
#         8.28446064e-04, 2.58920845e-02, 5.64751029e-03, 1.04366511e-04,
#         2.09229495e-02, 9.63062485e-05],
#        [1.97787056e-04, 4.99748113e-03, 6.76568061e-06, 4.62755025e-08,
#         1.05810443e-06, 1.59857605e-09, 9.52062873e-09, 1.04561494e-07,
#         9.94506419e-01, 2.90365395e-04],
#        [7.00312480e-02, 3.72275949e-01, 7.32663437e-04, 3.89846129e-04,
#         9.91593231e-04, 2.84191610e-05, 2.70691758e-04, 4.64785640e-04,
#         5.50219953e-01, 4.59488155e-03],
#        [3.03673685e-01, 6.50305524e-02, 6.12792000e-03, 9.55375098e-03,
#         7.04222312e-03, 3.93263414e-04, 1.35497961e-04, 1.02578721e-04,
#         6.05606556e-01, 2.33406317e-03],
#        [1.20077630e-05, 4.52098575e-05, 4.42416482e-02, 4.11270745e-02,
#         2.08516657e-01, 1.14472827e-03, 7.04623163e-01, 1.87126152e-05,
#         2.68200936e-04, 2.62149229e-06],
#        [4.00666868e-05, 1.11050482e-04, 1.19140567e-02, 3.94088775e-02,
#         2.28026565e-02, 5.28352335e-02, 8.69181573e-01, 3.32104298e-03,
#         3.63742001e-05, 3.49021720e-04]], dtype=float32)

# %%
np.argmax([5,12,67,9,])
# Out:
# 2

# %%
y_classes = [np.argmax(element) for element in y_pred]
y_classes
# Out:
# [3,
#  8,
#  8,
#  8,
#  6,
#  6,
#  1,
#  6,
#  3,
#  1,
#  4,
#  9,
#  5,
#  7,
#  9,
#  8,
#  5,
#  7,
#  8,
#  6,
#  7,
#  0,
#  4,
#  9,
#  4,
#  5,
#  4,
#  0,
#  9,
#  6,
#  6,
#  5,
#  4,
#  3,
#  9,
#  9,
#  4,
#  9,
#  9,
#  5,
#  4,
#  6,
#  7,
#  6,
#  0,
#  9,
#  3,
#  3,
#  7,
#  4,
#  9,
#  8,
#  6,
#  6,
#  8,
#  8,
#  7,
#  5,
#  2,
#  2,
#  7,
#  5,
#  6,
#  9,
#  3,
#  2,
#  1,
#  0,
#  5,
#  7,
#  8,
#  6,
#  8,
#  8,
#  0,
#  2,
#  0,
#  3,
#  3,
#  8,
#  8,
#  1,
#  1,
#  7,
#  5,
#  7,
#  2,
#  8,
#  9,
#  9,
#  8,
#  2,
#  8,
#  6,
#  4,
#  6,
#  6,
#  8,
#  0,
#  7,
#  4,
#  7,
#  6,
#  3,
#  1,
#  1,
#  8,
#  6,
#  8,
#  7,
#  4,
#  2,
#  2,
#  4,
#  9,
#  3,
#  0,
#  4,
#  3,
#  5,
#  8,
#  3,
#  1,
#  2,
#  8,
#  2,
#  8,
#  3,
#  3,
#  8,
#  4,
#  1,
#  8,
#  9,
#  1,
#  2,
#  9,
#  7,
#  2,
#  8,
#  3,
#  5,
#  6,
#  5,
#  8,
#  7,
#  6,
#  6,
#  7,
#  2,
#  8,
#  9,
#  6,
#  0,
#  0,
#  5,
#  2,
#  9,
#  3,
#  4,
#  2,
#  1,
#  6,
#  6,
#  0,
#  2,
#  8,
#  4,
#  9,
#  0,
#  9,
#  9,
#  9,
#  8,
#  9,
#  9,
#  3,
#  7,
#  5,
#  9,
#  9,
#  5,
#  2,
#  2,
#  4,
#  8,
#  6,
#  3,
#  3,
#  0,
#  6,
#  8,
#  7,
#  1,
#  7,
#  4,
#  8,
#  8,
#  7,
#  8,
#  5,
#  9,
#  8,
#  7,
#  1,
#  3,
#  0,
#  5,
#  7,
#  9,
#  7,
#  7,
#  5,
#  7,
#  8,
#  0,
#  7,
#  9,
#  8,
#  4,
#  7,
#  4,
#  9,
#  7,
#  3,
#  9,
#  3,
#  2,
#  3,
#  3,
#  3,
#  9,
#  5,
#  1,
#  8,
#  0,
#  4,
#  9,
#  5,
#  5,
#  1,
#  1,
#  8,
#  9,
#  0,
#  2,
#  1,
#  8,
#  2,
#  2,
#  7,
#  3,
#  9,
#  9,
#  2,
#  0,
#  3,
#  0,
#  8,
#  9,
#  8,
#  9,
#  3,
#  3,
#  0,
#  8,
#  2,
#  4,
#  7,
#  0,
#  7,
#  3,
#  6,
#  3,
#  8,
#  2,
#  0,
#  7,
#  4,
#  5,
#  9,
#  8,
#  6,
#  1,
#  9,
#  9,
#  9,
#  8,
#  7,
#  9,
#  1,
#  2,
#  6,
#  1,
#  3,
#  2,
#  6,
#  0,
#  0,
#  6,
#  6,
#  6,
#  5,
#  2,
#  6,
#  1,
#  8,
#  3,
#  9,
#  4,
#  8,
#  6,
#  8,
#  0,
#  3,
#  0,
#  7,
#  7,
#  5,
#  5,
#  3,
#  3,
#  6,
#  5,
#  5,
#  1,
#  7,
#  5,
#  4,
#  6,
#  1,
#  9,
#  6,
#  6,
#  6,
#  9,
#  3,
#  8,
#  3,
#  7,
#  4,
#  6,
#  2,
#  7,
#  8,
#  5,
#  7,
#  6,
#  8,
#  9,
#  9,
#  1,
#  8,
#  2,
#  6,
#  4,
#  5,
#  2,
#  1,
#  8,
#  9,
#  5,
#  8,
#  8,
#  9,
#  4,
#  1,
#  0,
#  0,
#  1,
#  2,
#  7,
#  9,
#  3,
#  2,
#  7,
#  9,
#  7,
#  2,
#  6,
#  6,
#  9,
#  0,
#  1,
#  5,
#  8,
#  7,
#  4,
#  3,
#  5,
#  1,
#  2,
#  6,
#  7,
#  9,
#  6,
#  2,
#  5,
#  0,
#  9,
#  9,
#  8,
#  7,
#  8,
#  8,
#  4,
#  0,
#  1,
#  8,
#  5,
#  7,
#  8,
#  5,
#  6,
#  9,
#  9,
#  3,
#  7,
#  2,
#  7,
#  4,
#  7,
#  8,
#  0,
#  2,
#  9,
#  5,
#  7,
#  6,
#  6,
#  4,
#  3,
#  3,
#  5,
#  9,
#  7,
#  2,
#  5,
#  3,
#  6,
#  1,
#  4,
#  9,
#  9,
#  5,
#  7,
#  5,
#  0,
#  2,
#  2,
#  1,
#  9,
#  7,
#  8,
#  9,
#  4,
#  4,
#  4,
#  4,
#  9,
#  7,
#  6,
#  1,
#  4,
#  4,
#  4,
#  4,
#  3,
#  7,
#  8,
#  4,
#  7,
#  8,
#  0,
#  3,
#  7,
#  4,
#  9,
#  5,
#  3,
#  8,
#  6,
#  8,
#  7,
#  7,
#  9,
#  9,
#  9,
#  4,
#  0,
#  1,
#  0,
#  8,
#  1,
#  8,
#  8,
#  0,
#  2,
#  2,
#  0,
#  4,
#  6,
#  3,
#  4,
#  9,
#  4,
#  7,
#  9,
#  9,
#  4,
#  5,
#  6,
#  6,
#  1,
#  5,
#  5,
#  8,
#  9,
#  7,
#  8,
#  7,
#  7,
#  0,
#  7,
#  0,
#  3,
#  4,
#  0,
#  0,
#  6,
#  9,
#  7,
#  9,
#  5,
#  6,
#  6,
#  6,
#  4,
#  0,
#  0,
#  1,
#  4,
#  6,
#  7,
#  5,
#  9,
#  1,
#  6,
#  5,
#  5,
#  3,
#  5,
#  8,
#  3,
#  9,
#  8,
#  6,
#  4,
#  3,
#  2,
#  0,
#  7,
#  6,
#  4,
#  4,
#  1,
#  9,
#  4,
#  9,
#  4,
#  6,
#  7,
#  1,
#  1,
#  5,
#  6,
#  8,
#  8,
#  7,
#  2,
#  4,
#  8,
#  8,
#  0,
#  0,
#  9,
#  7,
#  4,
#  8,
#  9,
#  6,
#  9,
#  2,
#  6,
#  1,
#  0,
#  7,
#  3,
#  5,
#  3,
#  8,
#  5,
#  0,
#  2,
#  1,
#  6,
#  8,
#  3,
#  3,
#  9,
#  6,
#  9,
#  8,
#  8,
#  5,
#  9,
#  6,
#  6,
#  4,
#  1,
#  7,
#  7,
#  1,
#  2,
#  7,
#  9,
#  9,
#  4,
#  4,
#  8,
#  8,
#  5,
#  6,
#  8,
#  4,
#  6,
#  8,
#  3,
#  0,
#  2,
#  3,
#  6,
#  0,
#  7,
#  9,
#  1,
#  4,
#  4,
#  4,
#  7,
#  7,
#  9,
#  3,
#  1,
#  9,
#  4,
#  1,
#  1,
#  4,
#  1,
#  9,
#  4,
#  7,
#  6,
#  3,
#  0,
#  9,
#  0,
#  9,
#  5,
#  6,
#  5,
#  4,
#  3,
#  2,
#  8,
#  4,
#  9,
#  8,
#  3,
#  9,
#  6,
#  2,
#  2,
#  9,
#  4,
#  9,
#  2,
#  6,
#  9,
#  4,
#  2,
#  0,
#  7,
#  8,
#  3,
#  8,
#  2,
#  7,
#  5,
#  7,
#  2,
#  6,
#  8,
#  7,
#  4,
#  2,
#  3,
#  8,
#  8,
#  6,
#  0,
#  8,
#  7,
#  3,
#  3,
#  3,
#  8,
#  2,
#  9,
#  7,
#  8,
#  8,
#  1,
#  8,
#  2,
#  1,
#  2,
#  6,
#  5,
#  4,
#  8,
#  7,
#  9,
#  8,
#  4,
#  1,
#  4,
#  1,
#  7,
#  5,
#  7,
#  7,
#  7,
#  2,
#  7,
#  6,
#  6,
#  2,
#  3,
#  9,
#  0,
#  9,
#  9,
#  2,
#  2,
#  6,
#  8,
#  2,
#  1,
#  7,
#  5,
#  6,
#  0,
#  1,
#  2,
#  4,
#  9,
#  5,
#  4,
#  9,
#  1,
#  6,
#  4,
#  2,
#  2,
#  7,
#  6,
#  0,
#  6,
#  9,
#  1,
#  7,
#  6,
#  7,
#  0,
#  3,
#  9,
#  6,
#  8,
#  0,
#  0,
#  7,
#  4,
#  7,
#  7,
#  4,
#  4,
#  7,
#  3,
#  7,
#  1,
#  2,
#  7,
#  4,
#  4,
#  8,
#  4,
#  7,
#  4,
#  2,
#  3,
#  7,
#  2,
#  1,
#  8,
#  9,
#  3,
#  9,
#  0,
#  6,
#  2,
#  0,
#  8,
#  7,
#  2,
#  4,
#  6,
#  5,
#  3,
#  1,
#  3,
#  2,
#  3,
#  4,
#  4,
#  9,
#  2,
#  9,
#  2,
#  7,
#  8,
#  7,
#  2,
#  2,
#  3,
#  7,
#  0,
#  2,
#  4,
#  5,
#  9,
#  8,
#  1,
#  0,
#  7,
#  7,
#  8,
#  7,
#  8,
#  4,
#  6,
#  6,
#  3,
#  0,
#  1,
#  6,
#  7,
#  0,
#  1,
#  3,
#  1,
#  4,
#  2,
#  3,
#  8,
#  4,
#  5,
#  4,
#  7,
#  8,
#  4,
#  3,
#  1,
#  9,
#  4,
#  0,
#  8,
#  8,
#  6,
#  4,
#  6,
#  7,
#  3,
#  1,
#  1,
#  3,
#  7,
#  7,
#  7,
#  2,
#  6,
#  6,
#  3,
#  8,
#  7,
#  8,
#  6,
#  8,
#  8,
#  5,
#  3,
#  5,
#  4,
#  1,
#  1,
#  4,
#  8,
#  8,
#  0,
#  6,
#  9,
#  9,
#  9,
#  5,
#  3,
#  8,
#  5,
#  0,
#  8,
#  4,
#  2,
#  3,
#  2,
#  7,
#  3,
#  2,
#  5,
#  9,
#  8,
#  9,
#  5,
#  7,
#  4,
#  0,
#  3,
#  0,
#  1,
#  3,
#  8,
#  7,
#  9,
#  6,
#  9,
#  4,
#  7,
#  0,
#  6,
#  7,
#  8,
#  9,
#  1,
#  1,
#  6,
#  6,
#  6,
#  6,
#  9,
#  1,
#  9,
#  9,
#  4,
#  5,
#  1,
#  4,
#  0,
#  6,
#  8,
#  1,
#  9,
#  6,
#  1,
#  5,
#  4,
#  7,
#  8,
#  3,
#  1,
#  2,
#  0,
#  1,
#  5,
#  8,
#  7,
#  6,
#  5,
#  8,
#  8,
#  3,
#  8,
#  ...]

# %%
plot_sample(x_test,y_test,4)

# %%
classes[y_classes[4]]
# Out:
# 'frog'

# %%
print('classification Report:\n',classification_report(y_test,y_classes))
# Out:
# classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.65      0.72      1000
#            1       0.86      0.76      0.81      1000
#            2       0.65      0.52      0.58      1000
#            3       0.53      0.48      0.50      1000
#            4       0.60      0.72      0.65      1000
#            5       0.64      0.54      0.59      1000
#            6       0.78      0.76      0.77      1000
#            7       0.68      0.81      0.74      1000
#            8       0.72      0.85      0.78      1000
#            9       0.72      0.86      0.78      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.70      0.70      0.69     10000
# weighted avg       0.70      0.70      0.69     10000
