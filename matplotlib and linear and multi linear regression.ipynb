# %%
from sklearn.cross_validation import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, 
                                                     random_state = 0)
   
# Feature Scaling
# Multilinear regression takes care of Feature Scaling
# So we need not do it manually 
   
   
# Fitting Multi Linear regression model to training model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
   
# predicting the test set results
y_pred = regressor.predict(xtest)
   
y_pred1 = y_pred
y_pred1 = y_pred1.reshape(-1,1)
   
print("\n   RESULT OF LINEAR REGRESSION PREDICTION : ")
print ("\nFirst 10 Predicted value : \n", y_pred1[0:10, :])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d0779fc76915> in <module>
# ----> 1 from sklearn.cross_validation import train_test_split
#       2 xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2,
#       3                                                      random_state = 0)
#       4
#       5 # Feature Scaling
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6]
y = [50,51,52,48,47,49]

# %%
plt.xlabel("day")
plt.ylabel('Tempreture')
plt.title('wheather')
plt.plot(x,y,color='green',linewidth=9 , linestyle='dotted')

# %%
days = [1,2,3,4,5,6]
max_t = [50,51,52,48,47,49]
min_t = [43,42,40,44,33,35]
avg_t = [45,48,48,46,40,42]

# %%
plt.xlabel('Days')
plt.ylabel('Tempreture')
plt.title("Wheather")

plt.plot(days,max_t,label = "Max")
plt.plot(days,min_t,label = 'Min')
plt.plot(days,avg_t,label = 'Avg')

plt.legend(loc='best')
plt.grid()

# %%
import numpy as  np

# %%
company = ['google','apple','ms','fb']
revenue = [90,136,89,27]
profit = [40,2,34,12]
xpos = np.arange(len(company))
xpos
plt.title('US Tech Stocks' )
plt.ylabel('revenue')
plt.xticks(xpos,company)
plt.bar(xpos-0.4,revenue,label = 'revenue')
plt.bar(xpos+0.4,profit,label="profit")
plt.legend()

# %%
plt.hist([revenue,profit])
# Out:
# (array([[0., 1., 0., 0., 0., 0., 2., 0., 0., 1.],
#         [2., 0., 2., 0., 0., 0., 0., 0., 0., 0.]]),
#  array([  2. ,  15.4,  28.8,  42.2,  55.6,  69. ,  82.4,  95.8, 109.2,
#         122.6, 136. ]),
#  <a list of 2 BarContainer objects>)

# %%
exp_vals = [1600,600,201,410,250]
labs = ['rent','food','phone bill','car' , 'other']
plt.pie(exp_vals,labels=labs,radius=2,autopct='%f%%',shadow=True,explode=(0,0,0.3,0.1,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x2a25deb50a0>,
# ...
#  [Text(-0.15679278450869116, 2.194405619461911, 'rent'),
#   Text(-1.5969756985519217, -1.513165099463572, 'food'),
#   Text(0.024375222952008713, -2.499881166876946, 'phone bill'),
#   Text(1.367707802970323, -1.8491553114041266, 'car'),
#   Text(2.1279786079033585, -0.5583073027515278, 'other')],
#  [Text(-0.08552333700474062, 1.1969485197064966, '52.270502%'),
#   Text(-0.8710776537555937, -0.8253627815255846, '19.601437%'),
#   Text(0.014625133771205227, -1.4999287001261674, '6.566481%'),
#   Text(0.7730522364614868, -1.0451747412284194, '13.394316%'),
#   Text(1.1607156043109226, -0.3045312560462879, '8.167265%')])

# %%
import pandas as pd
from sklearn import linear_model

# %%
data = {
    'area' : [2600,3000,3200,3600,4000],
    'price':[550000,565000,610000,680000,725000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area sqft')
plt.ylabel('price us')
plt.scatter(df.area,df.price,color='red', marker = '+')

# %%
X = df['area'].values.reshape(-1, 1)
y = df['price'].values.reshape(-1,1)
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
reg.predict(np.array(2600).reshape(-1, 1))
# Out:
# array([533664.38356164])

# %%
data = {
    'area' : [2600,3000,3200,3600,4000],
    'bedroom':[3.0,4.0,3,3.0,5.0],
    'age':[20,15,18,30,8],
    'price':[550000,565000,610000,680000,725000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    area  bedroom  age   price
# 0  2600      3.0   20  550000
# 1  3000      4.0   15  565000
# 2  3200      3.0   18  610000
# 3  3600      3.0   30  680000
# 4  4000      5.0    8  725000

# %%
import math
median_bedroom = math.floor(df.bedroom.median())

# %%
df.bedroom.fillna(median_bedroom)
# Out:
# 0    3.0
# 1    4.0
# 2    3.0
# 3    3.0
# 4    5.0
# Name: bedroom, dtype: float64

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area','bedroom','age']],df['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-ca6fb8308831> in <module>
# ----> 1 reg.fit(df[['area','bedroom','age']],df['price'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
reg.predict([[3000,3.0,4]])
# Out:
# array([8797053.5540741])

# %%
data = {
    'experience' : ['zero','zero','five','two','seven','three','ten','eleven'],
    'test_score':[8,8,6,10,9,7,7,7],
    'interview_score':[9,6,7,10,6,10,7,8],
    'salary':[50000,45000,60000,65000,70000,62000,72000,80000]
}
df = pd.DataFrame(data)

# %%
df.experience = df.experience.fillna("zero")
df
# Out:
#   experience  test_score  interview_score  salary
# 0       zero           8                9   50000
# 1       zero           8                6   45000
# 2       five           6                7   60000
# 3        two          10               10   65000
# 4      seven           9                6   70000
# 5      three           7               10   62000
# 6        ten           7                7   72000
# 7     eleven           7                8   80000

# %%
from word2number import w2n
df.experience=df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8                9   50000
# 1           0           8                6   45000
# 2           5           6                7   60000
# 3           2          10               10   65000
# 4           7           9                6   70000
# 5           3           7               10   62000
# 6          10           7                7   72000
# 7          11           7                8   80000

# %%
reg = linear_model.LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.fit(df[['experience','test_score','interview_score']],df['salary'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# array([53713.86677124])

# %%
reg.predict([[25,10,10]])
# Out:
# array([131737.29348178])
